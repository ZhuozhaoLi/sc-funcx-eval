# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import sqlite3
import seaborn as sns

sns.set(style='white', palette="Set2", color_codes=False)
sns.set_style("ticks")

# %matplotlib inline

# %%
def get_dataframes(query, databases):
    dataframes = []
    for database in databases:
        db = sqlite3.connect(database)
        dataframes += [pd.read_sql_query(query, db)]
    return pd.concat(dataframes)

# %%
query = 'select executor, tasks_per_trial, returned, start_submit, connected_workers, tag from tasks'
databases = [             
             'batch-dials2.db',
             'batch-xtract.db',
             'mnist-batch.db',
             ]
tasks = get_dataframes(query, databases)
tasks
# Out:
#        executor  tasks_per_trial      returned  start_submit  \
# 0   funcx_local                1  1.554847e+09  1.554847e+09
# 1   funcx_local                1  1.554847e+09  1.554847e+09
# 2   funcx_local                1  1.554847e+09  1.554847e+09
# 3   funcx_local                1  1.554847e+09  1.554847e+09
# 4   funcx_local                1  1.554847e+09  1.554847e+09
# 5   funcx_local                1  1.554847e+09  1.554847e+09
# 6   funcx_local                1  1.554847e+09  1.554847e+09
# 7   funcx_local                1  1.554847e+09  1.554847e+09
# 8   funcx_local                1  1.554847e+09  1.554847e+09
# 9   funcx_local                1  1.554847e+09  1.554847e+09
# 10  funcx_local                1  1.554847e+09  1.554847e+09
# 11  funcx_local                1  1.554847e+09  1.554847e+09
# 12  funcx_local                1  1.554848e+09  1.554847e+09
# 13  funcx_local                1  1.554848e+09  1.554848e+09
# 14  funcx_local                1  1.554848e+09  1.554848e+09
# 15  funcx_local                1  1.554848e+09  1.554848e+09
# 16  funcx_local                1  1.554848e+09  1.554848e+09
# 17  funcx_local                1  1.554849e+09  1.554848e+09
# 18  funcx_local                1  1.554930e+09  1.554930e+09
# 19  funcx_local                1  1.554930e+09  1.554930e+09
# 20  funcx_local                1  1.554930e+09  1.554930e+09
# 21  funcx_local                1  1.554930e+09  1.554930e+09
# 22  funcx_local                1  1.554930e+09  1.554930e+09
# 23  funcx_local                1  1.554930e+09  1.554930e+09
# 24  funcx_local                1  1.554930e+09  1.554930e+09
# 25  funcx_local                1  1.554930e+09  1.554930e+09
# 26  funcx_local                1  1.554930e+09  1.554930e+09
# 27  funcx_local                1  1.554930e+09  1.554930e+09
# 28  funcx_local                1  1.554930e+09  1.554930e+09
# 29  funcx_local                1  1.554930e+09  1.554930e+09
# ..          ...              ...           ...           ...
# 3   funcx_local                1  1.554925e+09  1.554925e+09
# 4   funcx_local                1  1.554925e+09  1.554925e+09
# 5   funcx_local                1  1.554925e+09  1.554925e+09
# 6   funcx_local                1  1.554925e+09  1.554925e+09
# 7   funcx_local                1  1.554925e+09  1.554925e+09
# 8   funcx_local                1  1.554925e+09  1.554925e+09
# 9   funcx_local                1  1.554925e+09  1.554925e+09
# 10  funcx_local                1  1.554925e+09  1.554925e+09
# 11  funcx_local                1  1.554925e+09  1.554925e+09
# 12  funcx_local                1  1.554925e+09  1.554925e+09
# 13  funcx_local                1  1.554925e+09  1.554925e+09
# 14  funcx_local                1  1.554925e+09  1.554925e+09
# 15  funcx_local                1  1.554925e+09  1.554925e+09
# 16  funcx_local                1  1.554925e+09  1.554925e+09
# 17  funcx_local                1  1.554925e+09  1.554925e+09
# 18  funcx_local                1  1.554925e+09  1.554925e+09
# 19  funcx_local                1  1.554925e+09  1.554925e+09
# 20  funcx_local                1  1.554925e+09  1.554925e+09
# 21  funcx_local                1  1.554925e+09  1.554925e+09
# 22  funcx_local                1  1.554925e+09  1.554925e+09
# 23  funcx_local                1  1.554925e+09  1.554925e+09
# 24  funcx_local                1  1.554925e+09  1.554925e+09
# 25  funcx_local                1  1.554925e+09  1.554925e+09
# 26  funcx_local                1  1.554925e+09  1.554925e+09
# 27  funcx_local                1  1.554925e+09  1.554925e+09
# 28  funcx_local                1  1.554925e+09  1.554925e+09
# 29  funcx_local                1  1.554925e+09  1.554925e+09
# 30  funcx_local                1  1.554925e+09  1.554925e+09
# 31  funcx_local                1  1.554925e+09  1.554925e+09
# 32  funcx_local                1  1.554925e+09  1.554925e+09
#
#     connected_workers                 tag
# 0                   1       bash_dials_32
# 1                   1       bash_dials_32
# 2                   1       bash_dials_32
# 3                   1       bash_dials_64
# 4                   1       bash_dials_64
# 5                   1       bash_dials_64
# 6                   1      bash_dials_128
# 7                   1      bash_dials_128
# 8                   1      bash_dials_128
# 9                   1      bash_dials_256
# 10                  1      bash_dials_256
# 11                  1      bash_dials_256
# 12                  1      bash_dials_512
# 13                  1      bash_dials_512
# 14                  1      bash_dials_512
# 15                  1     bash_dials_1024
# 16                  1     bash_dials_1024
# 17                  1     bash_dials_1024
# 18                  1        bash_dials_1
# 19                  1        bash_dials_1
# 20                  1        bash_dials_1
# 21                  1        bash_dials_2
# 22                  1        bash_dials_2
# 23                  1        bash_dials_2
# 24                  1        bash_dials_4
# 25                  1        bash_dials_4
# 26                  1        bash_dials_4
# 27                  1        bash_dials_8
# 28                  1        bash_dials_8
# 29                  1        bash_dials_8
# ..                ...                 ...
# 3                   1     mnist_predict_2
# 4                   1     mnist_predict_2
# 5                   1     mnist_predict_2
# 6                   1     mnist_predict_4
# 7                   1     mnist_predict_4
# 8                   1     mnist_predict_4
# 9                   1     mnist_predict_8
# 10                  1     mnist_predict_8
# 11                  1     mnist_predict_8
# 12                  1    mnist_predict_16
# 13                  1    mnist_predict_16
# 14                  1    mnist_predict_16
# 15                  1    mnist_predict_32
# 16                  1    mnist_predict_32
# 17                  1    mnist_predict_32
# 18                  1    mnist_predict_64
# 19                  1    mnist_predict_64
# 20                  1    mnist_predict_64
# 21                  1   mnist_predict_128
# 22                  1   mnist_predict_128
# 23                  1   mnist_predict_128
# 24                  1   mnist_predict_256
# 25                  1   mnist_predict_256
# 26                  1   mnist_predict_256
# 27                  1   mnist_predict_512
# 28                  1   mnist_predict_512
# 29                  1   mnist_predict_512
# 30                  1  mnist_predict_1024
# 31                  1  mnist_predict_1024
# 32                  1  mnist_predict_1024
#
# [99 rows x 6 columns]

# %%
tasks['completion time'] = tasks['returned'] - tasks['start_submit']
tasks['batch size'] = tasks['tag'].str.split('_').str[-1].map(int)
tasks['individual completion time'] = tasks['completion time'] / tasks['batch size']
tasks['app'] = tasks['tag'].str.split('_').str[:2].str.join('_')
tasks
# Out:
#        executor  tasks_per_trial      returned  start_submit  \
# 0   funcx_local                1  1.554847e+09  1.554847e+09
# 1   funcx_local                1  1.554847e+09  1.554847e+09
# 2   funcx_local                1  1.554847e+09  1.554847e+09
# 3   funcx_local                1  1.554847e+09  1.554847e+09
# 1                   1       bash_dials_32        13.083057          32
# 2                   1       bash_dials_32        12.769215          32
# 3                   1       bash_dials_64        22.742934          64
# 4                   1       bash_dials_64        22.433098          64
# 5                   1       bash_dials_64        22.579684          64
# 6                   1      bash_dials_128        40.014333         128
# 7                   1      bash_dials_128        40.254169         128
# 8                   1      bash_dials_128        38.902364         128
# 9                   1      bash_dials_256        67.915670         256
# 10                  1      bash_dials_256        69.023825         256
# 11                  1      bash_dials_256        69.575919         256
# 12                  1      bash_dials_512       132.435140         512
# 13                  1      bash_dials_512       132.616060         512
# 14                  1      bash_dials_512       134.373814         512
# 15                  1     bash_dials_1024       269.745944        1024
# 16                  1     bash_dials_1024       272.337898        1024
# 17                  1     bash_dials_1024       271.719839        1024
# 18                  1        bash_dials_1         6.144855           1
# 19                  1        bash_dials_1         6.106062           1
# 20                  1        bash_dials_1         6.023726           1
# 21                  1        bash_dials_2         5.947270           2
# 22                  1        bash_dials_2         5.940984           2
# 23                  1        bash_dials_2         6.125316           2
# 24                  1        bash_dials_4         6.075543           4
# 25                  1        bash_dials_4         6.120813           4
# 26                  1        bash_dials_4         6.074650           4
# 27                  1        bash_dials_8         6.481709           8
# 28                  1        bash_dials_8         6.125268           8
# 29                  1        bash_dials_8         6.124764           8
# ..                ...                 ...              ...         ...
# 3                   1     mnist_predict_2         1.736797           2
# 4                   1     mnist_predict_2         1.814325           2
# 5                   1     mnist_predict_2         1.704441           2
# 6                   1     mnist_predict_4         1.822919           4
# 7                   1     mnist_predict_4         1.869536           4
# 8                   1     mnist_predict_4         1.844058           4
# 9                   1     mnist_predict_8         1.726721           8
# 10                  1     mnist_predict_8         1.752341           8
# 11                  1     mnist_predict_8         1.776564           8
# 12                  1    mnist_predict_16         1.843492          16
# 13                  1    mnist_predict_16         1.762084          16
# 14                  1    mnist_predict_16         1.810843          16
# 15                  1    mnist_predict_32         1.801478          32
# 16                  1    mnist_predict_32         1.835449          32
# 17                  1    mnist_predict_32         1.893039          32
# 18                  1    mnist_predict_64         1.973555          64
# 19                  1    mnist_predict_64         1.949776          64
# 20                  1    mnist_predict_64         1.961154          64
# 21                  1   mnist_predict_128         2.209179         128
# 22                  1   mnist_predict_128         2.234198         128
# 23                  1   mnist_predict_128         2.226041         128
# 24                  1   mnist_predict_256         2.729604         256
# 25                  1   mnist_predict_256         2.763172         256
# 26                  1   mnist_predict_256         2.669344         256
# 27                  1   mnist_predict_512         3.877744         512
# 28                  1   mnist_predict_512         3.672099         512
# 29                  1   mnist_predict_512         3.784647         512
# 30                  1  mnist_predict_1024         5.904740        1024
# 31                  1  mnist_predict_1024         5.947683        1024
# 32                  1  mnist_predict_1024         6.188620        1024
#
#     individual completion time            app
# 0                     0.407574     bash_dials
# 1                     0.408846     bash_dials
# 2                     0.399038     bash_dials
# 3                     0.355358     bash_dials
# 4                     0.350517     bash_dials
# 5                     0.352808     bash_dials
# 6                     0.312612     bash_dials
# 7                     0.314486     bash_dials
# 8                     0.303925     bash_dials
# 9                     0.265296     bash_dials
# 10                    0.269624     bash_dials
# 11                    0.271781     bash_dials
# 12                    0.258662     bash_dials
# 13                    0.259016     bash_dials
# 14                    0.262449     bash_dials
# 15                    0.263424     bash_dials
# 16                    0.265955     bash_dials
# 17                    0.265351     bash_dials
# 18                    6.144855     bash_dials
# 19                    6.106062     bash_dials
# 20                    6.023726     bash_dials
# 21                    2.973635     bash_dials
# 22                    2.970492     bash_dials
# 23                    3.062658     bash_dials
# 24                    1.518886     bash_dials
# 25                    1.530203     bash_dials
# 26                    1.518663     bash_dials
# 27                    0.810214     bash_dials
# 28                    0.765658     bash_dials
# 29                    0.765596     bash_dials
# ..                         ...            ...
# 3                     0.868399  mnist_predict
# 4                     0.907162  mnist_predict
# 5                     0.852220  mnist_predict
# 6                     0.455730  mnist_predict
# 7                     0.467384  mnist_predict
# 8                     0.461015  mnist_predict
# 9                     0.215840  mnist_predict
# 10                    0.219043  mnist_predict
# 11                    0.222071  mnist_predict
# 12                    0.115218  mnist_predict
# 13                    0.110130  mnist_predict
# 14                    0.113178  mnist_predict
# 15                    0.056296  mnist_predict
# 16                    0.057358  mnist_predict
# 17                    0.059157  mnist_predict
# 18                    0.030837  mnist_predict
# 19                    0.030465  mnist_predict
# 20                    0.030643  mnist_predict
# 21                    0.017259  mnist_predict
# 22                    0.017455  mnist_predict
# 23                    0.017391  mnist_predict
# 24                    0.010663  mnist_predict
# 25                    0.010794  mnist_predict
# 26                    0.010427  mnist_predict
# 27                    0.007574  mnist_predict
# 28                    0.007172  mnist_predict
# 29                    0.007392  mnist_predict
# 30                    0.005766  mnist_predict
# 31                    0.005808  mnist_predict
# 32                    0.006044  mnist_predict
#
# [99 rows x 10 columns]

# %%
a = tasks['app'].unique()
for i in a: print(i)
# Out:
# bash_dials
# run_20k
# mnist_predict

# %%
labels = {
    'bash_dials': 'DIALS stills process',
    'mnist_predict': 'MNIST digit prediction',
    'run_20k': 'tabular file extraction',
    
}
fig, ax = plt.subplots(1, 1, figsize=(6,3.5))
markers = ['o', 's', 'p', '^', 'd', 'X']
marker_sizes = [6, 7, 7, 7, 7, 7, 6]
for i, app in enumerate(tasks['app'].unique()):
    cuts = (tasks['app'] == app) 
    df = tasks[cuts]
    if len(df) == 0: continue
    means = df.groupby('batch size', as_index=False).mean().sort_values('batch size')
    means.plot('batch size', 'individual completion time', marker=markers[i], ms=marker_sizes[i], 
               logy=False, logx=True, 
               #color=colors[i], 
               label=labels[app], ax=ax) # , yerr=list(standard_deviations['completion time'])


    #ax.set_ylim([1, 1000])
    #ax.set_xlim(10, 100000)
    ax.set_ylabel('Average latency per request (s)', fontsize=13, color='black')
    ax.set_xlabel('Batch size', labelpad=0, fontsize=13, color='black')
    ax.get_legend().remove()
    ax.tick_params(axis='y', which='minor')
    ax.tick_params(axis='both', which='major', pad=0, labelsize=13, labelcolor='black')

    plt.tick_params(axis='both', which='major', pad=0, labelsize=13, labelcolor='black')
    #legend = plt.legend(loc='center left', bbox_to_anchor=(0.8, 0.5), frameon=True, fontsize=13)
    legend = plt.legend(loc='best', 
                        ncol=1, 
                        #bbox_to_anchor=(-2.7, 1.2), 
                        fancybox=True, frameon=True, fontsize=13, framealpha=0.5)
    plt.setp(legend.get_texts(), color='black')
    legend.get_frame().set_edgecolor('black')
    legend.get_frame().set_linewidth(1)
    plt.subplots_adjust(wspace=0.2, hspace=0)

    plt.savefig('../png/batching.png', bbox_inches = "tight", dpi=1000)
